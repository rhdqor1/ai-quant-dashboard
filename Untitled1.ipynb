# %%
# !pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\python\anaconda\lib\site-packages (1.51.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in c:\python\anaconda\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\python\anaconda\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in c:\python\anaconda\lib\site-packages (from streamlit) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in c:\python\anaconda\lib\site-packages (from streamlit) (8.2.1)
# Requirement already satisfied: numpy<3,>=1.23 in c:\python\anaconda\lib\site-packages (from streamlit) (2.3.5)
# Requirement already satisfied: packaging<26,>=20 in c:\python\anaconda\lib\site-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\python\anaconda\lib\site-packages (from streamlit) (2.3.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in c:\python\anaconda\lib\site-packages (from streamlit) (12.0.0)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\python\anaconda\lib\site-packages (from streamlit) (6.33.6)
# Requirement already satisfied: pyarrow<22,>=7.0 in c:\python\anaconda\lib\site-packages (from streamlit) (21.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\python\anaconda\lib\site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\python\anaconda\lib\site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\python\anaconda\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\python\anaconda\lib\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\python\anaconda\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\python\anaconda\lib\site-packages (from streamlit) (3.1.45)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\python\anaconda\lib\site-packages (from streamlit) (6.5.1)
# Requirement already satisfied: jinja2 in c:\python\anaconda\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\python\anaconda\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.25.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\python\anaconda\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2.7.0)
# Requirement already satisfied: colorama in c:\python\anaconda\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\python\anaconda\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\python\anaconda\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\python\anaconda\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\python\anaconda\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\python\anaconda\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\python\anaconda\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\python\anaconda\lib\site-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python\anaconda\lib\site-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python\anaconda\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.11.12)
# Requirement already satisfied: attrs>=22.2.0 in c:\python\anaconda\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\python\anaconda\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\python\anaconda\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\python\anaconda\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.28.0)
# Requirement already satisfied: six>=1.5 in c:\python\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\python\anaconda\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.0.2)

# %%
# %%writefile app.py
import streamlit as st
import yfinance as yf
import pandas as pd

st.set_page_config(layout="wide")
st.title("🌏 한눈에 보는 글로벌 주도주 비교 대시보드 (미국 vs 한국)")

# 1. 독립적으로 데이터 가져오기 (정방향 대장주로 교체!)
st.write("데이터를 불러오는 중입니다. 잠시만 기다려주세요...")
us_data = yf.download("QQQ", period="1y")['Close']         # 나스닥 100 정방향
kr_data = yf.download("pip install plotly", period="1y")['Close']   # KODEX 200 정방향

# 2. 시차(Timezone) 강제 제거
us_data.index = us_data.index.tz_localize(None)
kr_data.index = kr_data.index.tz_localize(None)

# 3. 데이터 합치기
df = pd.concat([us_data, kr_data], axis=1).dropna()
df.columns = ['미국 QQQ (나스닥 100)', '한국 KODEX 200 (코스피)']

# ==========================================
# 화면 출력 부분
# ==========================================

# [첫 번째 줄] 독립적인 차트 나란히 보기
st.subheader("📊 국가별 대표 지수 추이 (나란히 보기)")
col1, col2 = st.columns(2)
with col1:
    st.write("🇺🇸 미국 QQQ (기술주 중심 우상향)")
    st.line_chart(df['미국 QQQ (나스닥 100)'])
with col2:
    st.write("🇰🇷 한국 KODEX 200 (한국 대형주 중심)")
    st.line_chart(df['한국 KODEX 200 (코스피)'])

st.markdown("---")

# [두 번째 줄] 하나의 차트에 겹쳐서 비교
st.subheader("📈 두 시장의 흐름 겹쳐서 비교 (0~1 정규화)")
st.info("달러와 원화는 단위가 달라서, 똑같은 비율로 흐름을 비교하기 위해 데이터를 스케일링(정규화)했습니다.")

# 0~1로 스케일링
df_norm = (df - df.min()) / (df.max() - df.min())
st.line_chart(df_norm)

# 상관관계 수치
correlation = df.corr().iloc[0, 1]
st.write(f"현재 두 시장의 가격 상관계수: **{correlation:.2f}**")
# Out:
# Overwriting app.py

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\허

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\python\anaconda\lib\site-packages (6.3.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\python\anaconda\lib\site-packages (from plotly) (2.7.0)
# Requirement already satisfied: packaging in c:\python\anaconda\lib\site-packages (from plotly) (25.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' 

# 1. 페이지 기본 설정
st.set_page_config(layout="wide", page_title="글로벌 퀀트 대시보드")
st.title("🌏 한·미·중 동조화 기반 AI 퀀트 대시보드")
st.markdown("과거 6년간의 미국(QQQ), 한국(KODEX 200), 중국(ASHR) 데이터를 학습하여 각국의 상승 확률과 방향성을 예측합니다.")

# 2. 데이터 로드 (캐싱)
@st.cache_data
def load_data():
    start_date = "2020-01-01"
    end_date = "2026-06-07"
    us_etf = yf.Ticker("QQQ").history(start=start_date, end=end_date)[['Close']].rename(columns={'Close': 'US_QQQ'})
    kr_etf = yf.Ticker("069500.KS").history(start=start_date, end=end_date)[['Close']].rename(columns={'Close': 'KR_KODEX'})
    cn_etf = yf.Ticker("ASHR").history(start=start_date, end=end_date)[['Close']].rename(columns={'Close': 'CN_ASHR'})

    us_etf.index = us_etf.index.tz_localize(None)
    kr_etf.index = kr_etf.index.tz_localize(None)
    cn_etf.index = cn_etf.index.tz_localize(None)

    df = us_etf.join(kr_etf, how='outer').join(cn_etf, how='outer')
    df.ffill(inplace=True)
    df.dropna(inplace=True)
    return df

df = load_data()

# 3. 모델 학습 (3개국 각각의 내일 오를 확률 계산 + 미국 시그널 데이터)
@st.cache_resource
def train_models(data_values):
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled_data = scaler.fit_transform(data_values)
    window_size = 10
    
    X = []
    for i in range(window_size, len(scaled_data)):
        X.append(scaled_data[i-window_size : i])
    X = np.array(X)
    
    results = {}
    names = ['US_QQQ', 'KR_KODEX', 'CN_ASHR']
    
    # 3개국 각각에 대해 빠르게 AI 모델을 학습시켜 '내일 확률'을 뽑아냅니다.
    for col_idx, name in enumerate(names):
        y = [1 if scaled_data[i, col_idx] > scaled_data[i-1, col_idx] else 0 for i in range(window_size, len(scaled_data))]
        y = np.array(y)
        
        split_index = int(len(X) * 0.8)
        X_train, X_test = X[:split_index], X[split_index:]
        y_train, y_test = y[:split_index], y[split_index:]
        
        # 빠른 학습을 위해 LSTM 층을 1개로 경량화
        model = Sequential()
        model.add(Input(shape=(X_train.shape[1], X_train.shape[2])))
        model.add(LSTM(units=50, return_sequences=False))
        model.add(Dropout(0.2))
        model.add(Dense(units=1, activation='sigmoid'))
        
        model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
        model.fit(X_train, y_train, epochs=10, batch_size=32, verbose=0)
        
        # 오늘(최근 10일) 데이터를 넣어서 내일 확률 예측
        latest_X = np.array([scaled_data[-window_size:]])
        next_prob = model.predict(latest_X, verbose=0)[0][0]
        results[f"{name}_prob"] = next_prob
        
        # 미국(QQQ)은 하단 시그널 차트를 위해 전체 테스트 예측값 저장
        if name == 'US_QQQ':
            results['us_pred_prob'] = model.predict(X_test, verbose=0)
            results['us_y_test'] = y_test
            
    return results

with st.spinner('🤖 AI가 3개국 각각의 상승 확률을 정밀 계산 중입니다... (약 15초 소요)'):
    ai_results = train_models(df.values)

st.markdown("---")
st.subheader("📊 글로벌 3대 시장 주도주 흐름 & AI 단기 예측")

# 4. 상단: 3국 지수 시각화 (Plotly 인터랙티브 차트 + 확률 뱃지)
col1, col2, col3 = st.columns(3)

# 차트 그리는 함수 (중복 코드 방지)
def draw_plotly_chart(dataframe, column_name, color):
    fig = px.line(dataframe, y=column_name, color_discrete_sequence=[color])
    fig.update_layout(
        xaxis_title="", yaxis_title="", 
        margin=dict(l=0, r=0, t=10, b=0), 
        height=250,
        hovermode="x unified" # 마우스 올리면 십자선 툴팁 표시
    )
    return fig

with col1:
    st.markdown("### 🇺🇸 미국 (QQQ)")
    prob = ai_results['US_QQQ_prob'] * 100
    st.info(f"🔮 AI 내일 상승 확률: **{prob:.1f}%**")
    st.plotly_chart(draw_plotly_chart(df, 'US_QQQ', '#1f77b4'), use_container_width=True)

with col2:
    st.markdown("### 🇰🇷 한국 (KODEX 200)")
    prob = ai_results['KR_KODEX_prob'] * 100
    st.warning(f"🔮 AI 내일 상승 확률: **{prob:.1f}%**")
    st.plotly_chart(draw_plotly_chart(df, 'KR_KODEX', '#ff7f0e'), use_container_width=True)

with col3:
    st.markdown("### 🇨🇳 중국 (ASHR)")
    prob = ai_results['CN_ASHR_prob'] * 100
    st.success(f"🔮 AI 내일 상승 확률: **{prob:.1f}%**")
    st.plotly_chart(draw_plotly_chart(df, 'CN_ASHR', '#2ca02c'), use_container_width=True)

st.markdown("---")

# 5. 하단: HTS 스타일 시그널 차트 (미국 QQQ 기준)
st.subheader("🔥 딥러닝(LSTM) 기반 나스닥(QQQ) 실전 매수 시그널")

y_pred_prob = ai_results['us_pred_prob']
y_test = ai_results['us_y_test']

y_pred_binary = (y_pred_prob > 0.5).astype(int)
hit_ratio = np.mean(y_pred_binary[:, 0] == y_test)

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

fig, ax = plt.subplots(figsize=(14, 6))
prob_1d = y_pred_prob.flatten()

ax.set_ylim(0.48, max(prob_1d) + 0.01)
ax.axhline(y=0.5, color='crimson', linestyle='--', label='기본 매수 기준점 (50%)', linewidth=2)

strong_buy_line = np.percentile(prob_1d, 75)
ax.axhline(y=strong_buy_line, color='goldenrod', linestyle=':', linewidth=2, label='강력 매수 기준선 (상위 25%)')

ax.plot(prob_1d, color='#1A5F7A', label='AI 예측 상승 확률', linewidth=2.5)

ax.fill_between(range(len(prob_1d)), 0.5, prob_1d,
                 where=(prob_1d > 0.5),
                 color='#22A699', alpha=0.25, label='일반 매수(Long) 유지 구간')

ax.fill_between(range(len(prob_1d)), strong_buy_line, prob_1d,
                 where=(prob_1d >= strong_buy_line),
                 color='#F2BE22', alpha=0.6, label='강력 매수 (Strong Buy) 구간')

ax.set_title(f'[한·미·중 동조화 AI 모델] 나스닥(QQQ) 방향성 예측 시그널 (적중률: {hit_ratio * 100:.1f}%)', fontsize=16, fontweight='bold', pad=15)
ax.set_xlabel('시간 흐름 (최근 테스트 기간 300일)', fontsize=12)
ax.set_ylabel('AI 상승 확신도 (Probability)', fontsize=12)
ax.legend(loc='lower right', frameon=True, shadow=True, fontsize=10)
ax.grid(True, alpha=0.3, linestyle='--')

st.pyplot(fig)
st.success("✅ 최신 시장 데이터를 반영한 한/미/중 AI 예측 및 시그널 업데이트가 완료되었습니다!")
# Out:
# 2026-06-08 17:59:24.158 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.158 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.159 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.159 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.159 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.159 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.160 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.160 No runtime found, using MemoryCacheStorageManager
# 2026-06-08 17:59:24.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.164 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.164 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.164 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.165 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.165 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.165 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.165 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.166 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.166 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.166 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.166 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.167 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.167 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.168 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.168 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.168 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.168 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.182 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-06-08 17:59:24.184 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.184 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.185 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.185 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.185 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.185 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.186 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.186 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.186 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.186 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.187 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.200 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-06-08 17:59:24.202 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.203 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.203 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.203 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.204 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.204 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.204 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.205 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.205 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.206 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.206 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.219 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-06-08 17:59:24.221 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.221 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.222 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.222 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.222 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.223 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.223 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.223 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.223 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.224 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.224 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.233 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.467 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.467 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.468 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.468 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.468 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-08 17:59:24.468 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
